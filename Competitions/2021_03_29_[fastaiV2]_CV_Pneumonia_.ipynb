# %% [markdown]
# <a href="https://colab.research.google.com/github/Svensone/kaggle/blob/main/2021_03_29_%5BfastaiV2%5D_CV_Pneumonia_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Computer Vision with Fastai/Pytorch
#
# ## **Detection of Pneumonia in lung scans**

# %% [markdown]
# ## 1. Setup
#
# ##############################

# %%
# Test this 

# https://www.kaggle.com/svensone/fastaiv2-cv-melanoma-dicom/edit

# %%
# update fastai to Version 2.0
# !pip install fastai --upgrade

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# import necessary libaries

#basics
import pandas as pd
import numpy as np
import random, os

# ML
import fastai
from fastai.vision.all import *
import torch

# Data Exploration / Visualization
import seaborn as sns

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

#check versions
print('Numpy        :', np.__version__)
print('fastai      :', fastai.__version__)
# Out:
# Numpy        : 1.19.5
# fastai      : 2.2.7

# %%
## for reproducability set seed
def seed_everything(seed=0):
  random.seed(seed)
  os.environ["PYTHONHASHSEED"] = str(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.backends.cudnn.deterministic = True
seed_everything()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Connect to kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a95b6ae2-cfd1-44bc-8133-b4375b73c481" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a95b6ae2-cfd1-44bc-8133-b4375b73c481">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"svensone","key":"a6d65a12358897f43d36dd282a344f9e"}'}

# %%
# Let's make sure the kaggle.json file is present.
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 64 Mar 29 21:27 kaggle.json

# %%
# Next, install the Kaggle API client.
# !pip install -q kaggle

# %%
# The Kaggle API client expects this file to be in ~/.kaggle,
# so move it there.
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# This permissions change avoids a warning on Kaggle tool startup.
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# 2. Data
#
# 2.1 Data from Kaggle
# 2.2 Data from github https://github.com/ieee8023/covid-chestxray-dataset
#
# *   List item
# *   List item

# %%
# List available datasets and download data

## Already downloaded - Skip
# !kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              221KB  2021-03-29 08:29:47           1233
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-02-17 16:10:44            920
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27            762
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19            338
# alsgroup/end-als                                            End ALS Kaggle Challenge                           12GB  2021-03-16 22:31:35            136
# simiotic/github-code-snippets                               GitHub Code Snippets                                7GB  2021-03-03 11:34:39             32
# fatiimaezzahra/famous-iconic-women                          Famous Iconic Women                               838MB  2021-02-28 14:56:00            268
# promptcloud/careerbuilder-job-listing-2020                  Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52            100
# mathurinache/twitter-edge-nodes                             Twitter Edge Nodes                                342MB  2021-03-08 06:43:04             53
# nickuzmenkov/nih-chest-xrays-tfrecords                      NIH Chest X-rays TFRecords                         11GB  2021-03-09 04:49:23            165
# mathurinache/the-lj-speech-dataset                          The LJ Speech Dataset                               3GB  2021-02-15 09:19:54             65
# nickuzmenkov/ranzcr-clip-kfold-tfrecords                    RANZCR CLiP KFold TFRecords                         2GB  2021-02-21 13:29:51             41
# coloradokb/dandelionimages                                  DandelionImages                                     4GB  2021-02-19 20:03:47            115
# imsparsh/accentdb-core-extended                             AccentDB - Core & Extended                          6GB  2021-02-17 14:22:54             27
# landrykezebou/lvzhdr-tone-mapping-benchmark-dataset-tmonet  LVZ-HDR Tone Mapping Benchmark Dataset (TMO-Net)   24GB  2021-03-01 05:03:40             24
# stuartjames/lights                                          LightS: Light Specularity Dataset                  18GB  2021-02-18 14:32:26             23
# shivamb/netflix-shows                                       Netflix Movies and TV Shows                         1MB  2021-01-18 16:20:26         123236
# jsphyg/weather-dataset-rattle-package                       Rain in Australia                                   4MB  2020-12-11 10:26:12          41922
# arashnic/hr-analytics-job-change-of-data-scientists         HR Analytics: Job Change of Data Scientists       295KB  2020-12-07 00:25:10          17438
# michau96/restaurant-business-rankings-2020                  Restaurant Business Rankings 2020                  16KB  2021-01-30 14:20:45          10993

# %%
# !pwd
# Out:
# /content

# %%
# change working dir to colab/pneumonia dir
# %cd drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData
# /content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData

# %%
# !ls
# Out:
# '2021.03.29 [fastaiV2] CV-mulitDatasets Pneumonia Kaggle.ipynb'
#  app.py
#  chest_xray
#  covid_xray
# '[fastAI] Pneumonia Ngrok-Streamlit.ipynb'
#  test_images

# %% [markdown]
# ## 2. Data Loading & Exploration
#
# ###############################

# %% [markdown]
# ### 2.1 Get the data
#
# run code only **once**

# %%
# only once - uncomment
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# Downloading chest-xray-pneumonia.zip to /content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData
# 100% 2.29G/2.29G [00:33<00:00, 102MB/s]
# 100% 2.29G/2.29G [00:33<00:00, 72.6MB/s]

# %%
# !unzip -q chest-xray-pneumonia.zip

# %%
# !kaggle datasets list -s covid-19
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.10 / client 1.5.4)
# ref                                                title                                                size  lastUpdated          downloadCount
# -------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# imdevskp/corona-virus-report                       COVID-19 Dataset                                     19MB  2020-08-07 03:47:47         128248
# sudalairajkumar/covid19-in-india                   COVID-19 in India                                   199KB  2020-12-09 06:18:02          95624
# allen-institute-for-ai/CORD-19-research-challenge  COVID-19 Open Research Dataset Challenge (CORD-19)    8GB  2021-03-09 14:24:18         119372
# roche-data-science-coalition/uncover               UNCOVER COVID-19 Challenge                          256MB  2020-08-10 14:53:45          19750
# gpreda/covid-world-vaccination-progress            COVID-19 World Vaccination Progress                 140KB  2021-03-15 08:28:01          27553
# andrewmvd/covid19-ct-scans                         COVID-19 CT scans                                     1GB  2020-04-23 12:29:33           7816
# tawsifurrahman/covid19-radiography-database        COVID-19 Radiography Database                       745MB  2021-03-06 18:17:46          18174
# sudalairajkumar/covid19-in-usa                     COVID-19 in USA                                      10MB  2020-12-07 06:23:33          15964
# sudalairajkumar/covid19-in-italy                   COVID-19 in Italy                                   441KB  2020-12-07 06:23:24          10423
# fireballbyedimyrnmom/us-counties-covid-19-dataset  US counties COVID 19 dataset                         12MB  2021-03-14 22:55:59          14607
# bachrr/covid-chest-xray                            COVID-19 chest xray                                 241MB  2020-05-15 00:30:50           6733
# headsortails/covid19-tracking-germany              COVID-19 Tracking Germany                             5MB  2021-03-14 14:15:54           4239
# iamhungundji/covid19-symptoms-checker              COVID-19 Symptoms Checker                           912KB  2020-03-21 06:05:59           6722
# mariaren/covid19-healthy-diet-dataset              COVID-19 Healthy Diet Dataset                        82KB  2021-02-07 21:50:53           8042
# kimjihoo/coronavirusdataset                        [NeurIPS 2020] Data Science for COVID-19 (DS4C)       7MB  2020-07-13 14:07:31          73344
# atilamadai/covid19                                 COVID-19                                            211MB  2021-03-14 07:56:02           1153
# tunguz/covid19-genomes                             COVID-19 Genomes                                    209KB  2020-04-21 16:50:25            834
# imdevskp/covid19-corona-virus-india-dataset        COVID-19 Corona Virus India Dataset                   3MB  2020-08-07 03:46:00          18380
# lalish99/covid19-mx                                COVID-19 MX                                          13MB  2020-07-24 03:43:20           1453
# hendratno/covid19-indonesia                        COVID-19 Indonesia Dataset                          386KB  2021-01-23 05:56:51           3040

# %%
# !makedir covid_chest_xray
# !kaggle datasets download bachrr/covid-chest-xray -p'/covid_chest_xray'
# Out:
# /bin/bash: makedir: command not found
# Downloading covid-chest-xray.zip to /covid_chest_xray
# 100% 241M/241M [00:03<00:00, 66.4MB/s]

# %%
# !unzip -q "/covid_chest_xray/covid-chest-xray.zip"

# %% [markdown]
# ### 1.2 Take a look

# %%
# Paths
path_covid = Path("/content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData/covid_xray")
path_pneumonia = Path("/content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData/chest_xray")

# %%
df_covid = pd.read_csv(path_covid/'metadata.csv')
df_covid.head()

# %%
df_covid.describe()
df_covid.columns
# Out:
# Index(['patientid', 'offset', 'sex', 'age', 'finding', 'survival', 'intubated',
#        'intubation_present', 'went_icu', 'in_icu', 'needed_supplemental_O2',
#        'extubated', 'temperature', 'pO2_saturation', 'leukocyte_count',
#        'neutrophil_count', 'lymphocyte_count', 'view', 'modality', 'date',
#        'location', 'folder', 'filename', 'doi', 'url', 'license',
#        'clinical_notes', 'other_notes', 'Unnamed: 28'],
#       dtype='object')

# %%
path_covid = Path("/content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData/covid_xray")
path_pneumonia = Path("/content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData/chest_xray")

path_train = path_pneumonia/"chest_xray/train"
path_train_normal = path_train/"NORMAL"
path_train_pneumonia = path_train/"PNEUMONIA"

print(len(path_train_normal.ls()), len(path_train_pneumonia.ls()))
# Out:
# 1342 3876

# %%
path_test_normal = path_pneumonia/'chest_xray/test/NORMAL'
path_test_pneumonia = path_pneumonia/'chest_xray/test/PNEUMONIA'
print(len(path_test_normal.ls()), len(path_test_pneumonia.ls()))
# path_pneumonia
# Out:
# 234 390

# %%
# # combining 2 Dataset
# Option 1. copy/paste folders together (3 folders(normal, pneum and covid))
# Option 2 with .add(ImageList) then only (normal/pneumonia as classes possible)
# src_combined = (ImageList.from_folder(path_data).add(ImageList.from_folder(path/'test-jpg-additional')))

# %% [markdown]
# ## 2. Data Preprocessing / Augmentation
#
# ##############################

# %%
# create Data with DataBlock Api (ImageDataBunch also possible but inflexible)
data_path = path_pneumonia/'chest_xray'

dls = ImageDataLoaders.from_folder(
    data_path, train='train', 
    valid_pct=0.2, 
    item_tfms=Resize(224), 
    bs = 64, 
    seed=0)

# %%
dls.show_batch()

# %% [markdown]
# ## 4. CNN Model
#
# #########################
#
# - Training and Fine_tuning
# - interpretation and results

# %% [markdown]
# ### 4.1 Training

# %%
learn = cnn_learner(dls, resnet34, metrics=[error_rate, accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.014454397559165954, lr_steep=0.005248074419796467)

# %%
learn.fit_one_cycle(5, lr_max=1e-2 , cbs=EarlyStoppingCallback(patience=3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.325853</td>
#       <td>0.617195</td>
#       <td>0.263877</td>
#       <td>0.736123</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.210156</td>
#       <td>1.039873</td>
#       <td>0.258753</td>
#       <td>0.741247</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.149127</td>
#       <td>1.078685</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.092791</td>
#       <td>1.295602</td>
#       <td>0.260461</td>
#       <td>0.739539</td>
#       <td>01:30</td>
#     </tr>
#   </tbody>
# </table>
# No improvement since epoch 0: early stopping

# %%
learn.unfreeze()
learn.fit_one_cycle(4, lr_max= 1e-4, cbs=EarlyStoppingCallback(patience=3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.083296</td>
#       <td>1.480528</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.068195</td>
#       <td>2.109633</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.045077</td>
#       <td>2.082513</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.028180</td>
#       <td>2.062042</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:33</td>
#     </tr>
#   </tbody>
# </table>
# No improvement since epoch 0: early stopping

# %%
learn.save('resent34_stage_1')
# Out:
# Path('/content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData/chest_xray/chest_xray/models/resent34_stage_1.pth')

# %% [markdown]
# ### 4.2 Evaluation

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(5,5), dpi=60)

# %%
learn.show_results()

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.121570</td>
#       <td>4.917150</td>
#       <td>0.385141</td>
#       <td>0.614859</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.138863</td>
#       <td>1.454223</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.121171</td>
#       <td>1.953449</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.082200</td>
#       <td>1.551301</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.051980</td>
#       <td>1.439324</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fine_tune(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.046111</td>
#       <td>1.278586</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:31</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.038187</td>
#       <td>1.459890</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.037559</td>
#       <td>1.500762</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.030354</td>
#       <td>1.898552</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.023444</td>
#       <td>2.082859</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.017566</td>
#       <td>2.161468</td>
#       <td>0.259607</td>
#       <td>0.740393</td>
#       <td>01:32</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Prediction
#
# #####################

# %%
learn = cnn_learner(dls, resnet34, metrics=[error_rate, accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
learn.load('/content/drive/MyDrive/Colab Notebooks/fastai_pneumonia_KaggleData/chest_xray/chest_xray/models/resent34_stage_2')

# %%
preds, _ = learn.get_preds()
preds.shape
# Out:
# torch.Size([1171, 2])

# %%
test_items = get_image_files(path_pneumonia/'chest_xray/test')
dl_test = learn.dls.test_dl(test_items, rm_type_tfms=1, bs=64)

# %%
y_pred, _ = learn.get_preds(dl=dl_test)
thresh = 0.5
yhat_test = [' '.join([learn.dls.vocab[i] for i,p in enumerate(pred) if p > thresh]) for pred in y_pred.numpy()]

# %%
y_test = list(map(lambda x: x.parents[0].name, test_items))

# %%
results = pd.DataFrame({'target': y_test, 'pred': yhat_test})

accuracy1 = results[results.target == results.pred].shape[0]

accuracy = accuracy1 / results.shape[0]
accuracy
# Out:
# 0.6057692307692307

# %% [markdown]
# ## 5. Export

# %%
learn.export('resnet34_stage_2.pkl')

# %% [markdown]
# # Notes
# #######################
#
# 2021 April:
# - train more with bigger img size Resize()
# - calculate Sensitivity / Specificity
#
# 2021 March (Accuracy 74%, 14 epochs)
# - Model and Training on Colab
# - deployed on share.streamlit.io
# - colab & streamlit - ngrok (only working when colab notebook running in background - see notebook) - deploy
# - medical images : https://docs.fast.ai/tutorial.medical_imaging.html
#
# 2021.03.13 :
# - refactor for Fastai Version 2
#
# 2020 Juni (fastai V1, accuracy= 97% (only pneumonia img))
# - 20.06.2020 moved to Colab since no GPU in Kaggle
# - 23.06 ResNet34: accuracy= 97% (only pneumonia img)
# - 23.06 adding covid data
#     - new branch
#     - new File (in Kaggle dir) for joining Datasets
